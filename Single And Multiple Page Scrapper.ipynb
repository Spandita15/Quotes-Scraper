# %%
import requests
import pandas as pd
from tqdm import tqdm # this library shows progress so as to what percentage of work is done
from bs4 import BeautifulSoup

# %%
link = "https://quotes.toscrape.com/"

# %%
res = requests.get(link)

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# Code [200] means that the content is successfully imported.

# %%
# To get the whole code
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n    \n    \n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span
# ...

# %%
# to show it in a better manner
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %% [markdown]
# # <font color = "green">SINGLE PAGE SCRAPPER</font>

# %% [markdown]
# # Saving the page offline/on your system

# %%
# save the text in a variable
html = res.text # html has a string data type by default

# %%
# now create a html based file and open it in the write mode
fd = open("main.html", "w", encoding = "utf-8")
# write the html content in that new file
fd.write(html)
fd.close()

# %% [markdown]
# The file is stored in the same directory but it does not look exactly the same as in the web page as the style and some other parameters are not imported but the text remains the same.

# %% [markdown]
# # Scraping Quotes

# %% [markdown]
# Soup is a whole string (here html) on which we can perform several operations. We are going to extract the whole Soup using the library BeautifulSoup.

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
soup.find("span", class_="text") # find() only finds the first instance of the tag mentioned (here span)
# Out:
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>

# %%
soup.find("span", class_="text").text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
print(soup.find("span", class_="text").text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”

# %%
# We can also perform slicing on the text
print(soup.find("span", class_="text").text[1:-1])
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.

# %%
# to print all the instances, we use find_all()
soup.find_all("span", class_="text")
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>,
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>,
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>,
# ...

# %%
for quotes in soup.find_all("span", class_="text"):
    print(quotes.text[1:-1])
    print()
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
#
# It is our choices, Harry, that show what we truly are, far more than our abilities.
#
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
#
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
#
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
#
# Try not to become a man of success. Rather become a man of value.
#
# It is better to be hated for what you are than to be loved for what you are not.
#
# I have not failed. I've just found 10,000 ways that won't work.
#
# A woman is like a tea bag; you never know how strong it is until it's in hot water.
#
# A day without sunshine is like, you know, night.

# %%
quotes = []
for quote in soup.find_all("span", class_="text"):
    quotes.append(quote.text[1:-1])

# %%
quotes
# Out:
# ['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking',
#  'It is our choices, Harry, that show what we truly are, far more than our abilities.”It is our choices, Harry, that show what we truly are, far more than our abilities',
#  'There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle',
#  'The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid',
# ...

# %% [markdown]
# # Scraping Quotes with Author Details

# %%
soup.find_all("div", class_="quote")
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# ...

# %%
# to find the details of first quote, its author and the author details along with the tags
soup.find_all("div", class_="quote")[0]
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>

# %%
for sp in soup.find_all("div", class_="quote"):
    print(sp)
    print()
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>
#
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# ...

# %%
data = []
for sp in soup.find_all("div", class_="quote"):
    quote = sp.find("span", class_="text").text[1:-1]
    author = sp.find("small", class_="author").text
    author_id = sp.find("a").get("href")
    tags = []
    for tag in sp.find_all("a", class_="tag"):
        tags.append(tag.text)
    tags = ",".join(tags)
    print("Quote : ",quote)
    print("Author : ",author)
    print("Author_ID : ",author_id)
    print("Tags : ",tags)
    data.append([quote, author, author_id, tags])
    print("-"*40)
# Out:
# Quote :  The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking
# Author :  Albert Einstein
# Author_ID :  /author/Albert-Einstein
# Tags :  change,deep-thoughts,thinking,world
# ----------------------------------------
# Quote :  It is our choices, Harry, that show what we truly are, far more than our abilities.”It is our choices, Harry, that show what we truly are, far more than our abilities
# Author :  J.K. Rowling
# Author_ID :  /author/J-K-Rowling
# Tags :  abilities,choices
# ----------------------------------------
# Quote :  There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle
# ...

# %%
data
# Out:
# [['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'change,deep-thoughts,thinking,world'],
#  ['It is our choices, Harry, that show what we truly are, far more than our abilities.”It is our choices, Harry, that show what we truly are, far more than our abilities',
#   'J.K. Rowling',
#   '/author/J-K-Rowling',
#   'abilities,choices'],
#  ['There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'inspirational,life,live,miracle,miracles'],
# ...

# %%
df = pd.DataFrame(data, columns = ["Quote", "Author", "Author_ID", "Tags"])

# %%
df
# Out:
#                                                Quote             Author  \
# 0  The world as we have created it is a process o...    Albert Einstein
# 1  It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2  There are only two ways to live your life. One...    Albert Einstein
# 3  The person, be it gentleman or lady, who has n...        Jane Austen
# 4  Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5  Try not to become a man of success. Rather bec...    Albert Einstein
# 6  It is better to be hated for what you are than...         André Gide
# 7  I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8  A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9  A day without sunshine is like, you know, nigh...       Steve Martin
#
#                    Author_ID                                      Tags
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %%
df.to_csv("Quotes.csv", index = False)

# %% [markdown]
# # <font color = "green">MULTIPLE PAGE SCRAPPER</font>

# %%
# we already have page 1 scraped then to scrape the remaining pages 
for page in range(2,11):
    print("https://quotes.toscrape.com/page/" + str(page))
# Out:
# https://quotes.toscrape.com/page/2
# https://quotes.toscrape.com/page/3
# https://quotes.toscrape.com/page/4
# https://quotes.toscrape.com/page/5
# https://quotes.toscrape.com/page/6
# https://quotes.toscrape.com/page/7
# https://quotes.toscrape.com/page/8
# https://quotes.toscrape.com/page/9
# https://quotes.toscrape.com/page/10

# %%
data = []
for page in tqdm(range(1,11)):
    link = "https://quotes.toscrape.com/page/" + str(page)
    res = requests.get(link)
    soup = BeautifulSoup(res.text, "html.parser")
    for sp in soup.find_all("div", class_="quote"):
        quote = sp.find("span", class_="text").text[1:-1]
        author = sp.find("small", class_="author").text
        author_id = sp.find("a").get("href")
        tags = []
        for tag in sp.find_all("a", class_="tag"):
            tags.append(tag.text)
        tags = ",".join(tags)
        data.append([quote, author, author_id, tags])
# Out:
# 100%|██████████| 10/10 [00:24<00:00,  2.50s/it]

# %%
# now there are 10 quotes on each of the 10 pages so data should have 100 elements
len(data)
# Out:
# 100

# %%
df = pd.DataFrame(data, columns = ["Quote", "Author", "Author_ID", "Tags"])

# %%
df["Author_Link"] = "https://quotes.toscrape.com" + df["Author_ID"]

# %%
df
# Out:
#                                                 Quote              Author  \
# 0   The world as we have created it is a process o...     Albert Einstein
# 1   It is our choices, Harry, that show what we tr...        J.K. Rowling
# 2   There are only two ways to live your life. One...     Albert Einstein
# 3   The person, be it gentleman or lady, who has n...         Jane Austen
# 4   Imperfection is beauty, madness is genius and ...      Marilyn Monroe
# ..                                                ...                 ...
# 95  You never really understand a person until you...          Harper Lee
# 96  You have to write the book that wants to be wr...   Madeleine L'Engle
# 97  Never tell the truth to people who are not wor...          Mark Twain
# 98          A person's a person, no matter how small.           Dr. Seuss
# 99  ... a mind needs books as a sword needs a whet...  George R.R. Martin
#
#                     Author_ID  \
# 0     /author/Albert-Einstein
# ...

# %%
df.to_csv("Quotes_all_pages.csv", index = False)
